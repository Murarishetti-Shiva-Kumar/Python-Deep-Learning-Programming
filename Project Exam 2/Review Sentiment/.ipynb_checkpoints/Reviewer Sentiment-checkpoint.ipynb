# %%
#Importing required packages

import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import re

from sklearn import preprocessing
from sklearn.model_selection import train_test_split #Package for splitting the data

from sklearn.preprocessing import LabelEncoder #Package for conversion of categorical to Numerical

from keras import layers

from keras.preprocessing.text import Tokenizer #Tokenization
from keras.preprocessing.sequence import pad_sequences #Add zeros or crop based on the length

from keras.utils.np_utils import to_categorical

from keras.constraints import maxnorm

from keras.models import Sequential #Sequential Neural Network
from keras.layers import Embedding, Conv1D, Dropout, MaxPooling1D, Flatten, Dense, LSTM, GlobalMaxPooling1D, SpatialDropout1D #For layers in Neural Network

# %%
df=pd.read_csv(('train.tsv'), delimiter='\t') #Loading the file

# %%
df.head() #Top 5
# Out:
#    PhraseId  SentenceId                                             Phrase  \
# 0         1           1  A series of escapades demonstrating the adage ...
# 1         2           1  A series of escapades demonstrating the adage ...
# 2         3           1                                           A series
# 3         4           1                                                  A
# 4         5           1                                             series
#
#    Sentiment
# 0          1
# 1          2
# 2          2
# 3          2
# 4          2

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 156060 entries, 0 to 156059
# Data columns (total 4 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   PhraseId    156060 non-null  int64
#  1   SentenceId  156060 non-null  int64
#  2   Phrase      156060 non-null  object
#  3   Sentiment   156060 non-null  int64
# dtypes: int64(3), object(1)
# memory usage: 4.8+ MB

# %%
df.isna().sum()
# Out:
# PhraseId      0
# SentenceId    0
# Phrase        0
# Sentiment     0
# dtype: int64

# %%
X = df['Phrase']

# %%
y = df['Sentiment']

# %%
X=X.apply(lambda x: x.lower())
X=X.apply((lambda x: re.sub('[^a-zA-Z0-9\s]', '', x)))

# %%
X
# Out:
# 0         a series of escapades demonstrating the adage ...
# 1         a series of escapades demonstrating the adage ...
# 2                                                  a series
# 3                                                         a
# 4                                                    series
#                                 ...
# 156055                                             hearst s
# 156056                            forced avuncular chortles
# 156057                                   avuncular chortles
# 156058                                            avuncular
# 156059                                             chortles
# Name: Phrase, Length: 156060, dtype: object

# %%
max_features = 2000
tokenizer = Tokenizer(num_words=max_features, split=' ')
tokenizer.fit_on_texts(X.values)
X = tokenizer.texts_to_sequences(X.values)
X = pad_sequences(X)

# %%
embed_dim = 128
# lstm_out = 196 
num_classes = 5

# %%
X.shape[1]
# Out:
# 45

# %% [markdown]
# ## Include Embedding layer in the design of your models

# %%
model = Sequential()
model.add(Embedding(13734, embed_dim, input_length=X.shape[1]))
model.add(Dropout(0.2))
model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu', strides=1))
model.add(GlobalMaxPooling1D())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# %%
from sklearn.preprocessing import LabelEncoder
from keras.utils.np_utils import to_categorical
label_encoder = LabelEncoder()
integer_encoded = label_encoder.fit_transform(y)
y = to_categorical(integer_encoded)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=37)

# %%
accuracy_val = model.fit(X_train, y_train, epochs=5, batch_size=512, validation_data=(X_test,y_test))
# Out:
# Epoch 1/5
# 229/229 [==============================] - 63s 273ms/step - loss: 1.1566 - accuracy: 0.5531 - val_loss: 1.0148 - val_accuracy: 0.6033
# Epoch 2/5
# 229/229 [==============================] - 60s 261ms/step - loss: 0.9825 - accuracy: 0.6137 - val_loss: 0.9793 - val_accuracy: 0.6148
# Epoch 3/5
# 229/229 [==============================] - 61s 266ms/step - loss: 0.9371 - accuracy: 0.6316 - val_loss: 0.9502 - val_accuracy: 0.6256
# Epoch 4/5
# 229/229 [==============================] - 56s 244ms/step - loss: 0.9002 - accuracy: 0.6471 - val_loss: 0.9334 - val_accuracy: 0.6315
# Epoch 5/5
# 229/229 [==============================] - 58s 253ms/step - loss: 0.8680 - accuracy: 0.6590 - val_loss: 0.9229 - val_accuracy: 0.6356

# %%
y_pred=model.predict_classes(X_test[:1])
print(y_pred[0]," PREDICTED LABEL")
# Out:
# WARNING:tensorflow:From <ipython-input-17-ffce7685b9c7>:1: Sequential.predict_classes (from tensorflow.python.keras.engine.sequential) is deprecated and will be removed after 2021-01-01.
# Instructions for updating:
# Please use instead:* `np.argmax(model.predict(x), axis=-1)`,   if your model does multi-class classification   (e.g. if it uses a `softmax` last-layer activation).* `(model.predict(x) > 0.5).astype("int32")`,   if your model does binary classification   (e.g. if it uses a `sigmoid` last-layer activation).
# 3  PREDICTED LABEL

# %%
accuracy_val.history.keys()
# Out:
# dict_keys(['loss', 'accuracy', 'val_loss', 'val_accuracy'])

# %% [markdown]
# ## Plot loss of the model and report if you see any overfitting problem

# %%
plt.plot(accuracy_val.history['loss'])
plt.plot(accuracy_val.history['val_loss'])
plt.title('model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['loss','Validation Loss'], loc='upper right')
plt.show()

# %%
plt.plot(accuracy_val.history['accuracy'])
plt.plot(accuracy_val.history['val_accuracy'])
plt.plot(accuracy_val.history['loss'])
plt.plot(accuracy_val.history['val_loss'])
plt.title('Loss Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accuracy', 'validation accuracy','loss','val_loss'], loc='upper right')
plt.show()

# %% [markdown]
# ## What techniques you can apply to fix overfitting model

# %% [markdown]
# https://towardsdatascience.com/preventing-deep-neural-network-from-overfitting-953458db800a
#
# https://www.tensorflow.org/api_docs/python/tf/keras/callbacks/EarlyStopping

# %%
#Using Early Stopping to hadle Overfitting

from keras.callbacks import EarlyStopping

model = Sequential()
model.add(Embedding(13734, embed_dim, input_length=X.shape[1]))
model.add(Dropout(0.2))
model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu', strides=1))
model.add(GlobalMaxPooling1D())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
# In min mode, training will stop when the quantity monitored has stopped decreasing
#verbosity mode

accuracy_val_early_stop = model.fit(X_train, y_train, epochs=5, batch_size=512, validation_data=(X_test,y_test), callbacks=[es])
# Out:
# Epoch 1/5
# 229/229 [==============================] - 56s 242ms/step - loss: 1.1594 - accuracy: 0.5521 - val_loss: 1.0224 - val_accuracy: 0.6006
# Epoch 2/5
# 229/229 [==============================] - 50s 219ms/step - loss: 0.9875 - accuracy: 0.6117 - val_loss: 0.9846 - val_accuracy: 0.6134
# Epoch 3/5
# 229/229 [==============================] - 48s 211ms/step - loss: 0.9419 - accuracy: 0.6303 - val_loss: 0.9516 - val_accuracy: 0.6237
# Epoch 4/5
# 229/229 [==============================] - 48s 210ms/step - loss: 0.9029 - accuracy: 0.6449 - val_loss: 0.9390 - val_accuracy: 0.6279
# Epoch 5/5
# 229/229 [==============================] - 47s 207ms/step - loss: 0.8739 - accuracy: 0.6555 - val_loss: 0.9185 - val_accuracy: 0.6369

# %%
plt.plot(accuracy_val_early_stop.history['loss'])
plt.plot(accuracy_val_early_stop.history['val_loss'])
plt.title('model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['loss','Validation Loss'], loc='upper right')
plt.show()

# %%
plt.plot(accuracy_val_early_stop.history['accuracy'])
plt.plot(accuracy_val_early_stop.history['val_accuracy'])
plt.plot(accuracy_val_early_stop.history['loss'])
plt.plot(accuracy_val_early_stop.history['val_loss'])
plt.title('Loss Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accuracy', 'validation accuracy','loss','val_loss'], loc='upper right')
plt.show()

# %%
#Using Early Stopping to hadle Overfitting

from keras.callbacks import EarlyStopping

model = Sequential()
model.add(Embedding(13734, embed_dim, input_length=X.shape[1]))
model.add(Dropout(0.2))
model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu', strides=1))
model.add(GlobalMaxPooling1D())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='max', verbose=1)
# in "max" mode it will stop when the quantity monitored has stopped increasing
#verbosity mode

accuracy_val_early_stop = model.fit(X_train, y_train, epochs=5, batch_size=512, validation_data=(X_test,y_test), callbacks=[es])
# Out:
# Epoch 1/5
# 229/229 [==============================] - 50s 219ms/step - loss: 1.1750 - accuracy: 0.5456 - val_loss: 1.0295 - val_accuracy: 0.5986
# Epoch 2/5
# 229/229 [==============================] - 56s 246ms/step - loss: 0.9906 - accuracy: 0.6114 - val_loss: 0.9835 - val_accuracy: 0.6140
# Epoch 00002: early stopping

# %%
plt.plot(accuracy_val_early_stop.history['loss'])
plt.plot(accuracy_val_early_stop.history['val_loss'])
plt.title('model Loss')
plt.ylabel('Loss')
plt.xlabel('epoch')
plt.legend(['loss','Validation Loss'], loc='upper right')
plt.show()

# %%
plt.plot(accuracy_val_early_stop.history['accuracy'])
plt.plot(accuracy_val_early_stop.history['val_accuracy'])
plt.plot(accuracy_val_early_stop.history['loss'])
plt.plot(accuracy_val_early_stop.history['val_loss'])
plt.title('Loss Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accuracy', 'validation accuracy','loss','val_loss'], loc='upper right')
plt.show()

# %%
#Using Early Stopping to hadle Overfitting

from keras.callbacks import EarlyStopping

model = Sequential()
model.add(Embedding(13734, embed_dim, input_length=X.shape[1]))
model.add(Dropout(0.2))
model.add(Conv1D(64, kernel_size=3, padding='same', activation='relu', strides=1))
model.add(GlobalMaxPooling1D())
model.add(Dense(128, activation='relu'))
model.add(Dropout(0.2))
model.add(Dense(num_classes, activation='softmax'))
model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1)
# In min mode, training will stop when the quantity monitored has stopped decreasing
#verbosity mode

accuracy_val_early_stop = model.fit(X_train, y_train, epochs=15, batch_size=512, validation_data=(X_test,y_test), callbacks=[es])
# Out:
# Epoch 1/15
# 229/229 [==============================] - 60s 263ms/step - loss: 1.1756 - accuracy: 0.5458 - val_loss: 1.0170 - val_accuracy: 0.6014
# Epoch 2/15
# 229/229 [==============================] - 66s 286ms/step - loss: 0.9872 - accuracy: 0.6121 - val_loss: 0.9722 - val_accuracy: 0.6177
# Epoch 3/15
# 229/229 [==============================] - 54s 234ms/step - loss: 0.9381 - accuracy: 0.6321 - val_loss: 0.9464 - val_accuracy: 0.6245
# Epoch 4/15
# 229/229 [==============================] - 63s 277ms/step - loss: 0.8980 - accuracy: 0.6471 - val_loss: 0.9440 - val_accuracy: 0.6273
# Epoch 5/15
# 229/229 [==============================] - 54s 238ms/step - loss: 0.8675 - accuracy: 0.6597 - val_loss: 0.9281 - val_accuracy: 0.6328
# Epoch 6/15
# 229/229 [==============================] - 58s 255ms/step - loss: 0.8419 - accuracy: 0.6699 - val_loss: 0.9139 - val_accuracy: 0.6378
# Epoch 7/15
# 229/229 [==============================] - 57s 247ms/step - loss: 0.8211 - accuracy: 0.6767 - val_loss: 0.9117 - val_accuracy: 0.6399
# Epoch 8/15
# 229/229 [==============================] - 57s 251ms/step - loss: 0.8068 - accuracy: 0.6825 - val_loss: 0.9209 - val_accuracy: 0.6347
# Epoch 00008: early stopping

# %%
plt.plot(accuracy_val_early_stop.history['accuracy'])
plt.plot(accuracy_val_early_stop.history['val_accuracy'])
plt.plot(accuracy_val_early_stop.history['loss'])
plt.plot(accuracy_val_early_stop.history['val_loss'])
plt.title('Loss Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['accuracy', 'validation accuracy','loss','val_loss'], loc='upper right')
plt.show()
